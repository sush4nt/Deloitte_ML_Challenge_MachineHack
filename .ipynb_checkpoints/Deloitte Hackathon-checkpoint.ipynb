# %% [markdown]
# # MachineHack Deloitte Hackathon

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# For Encoding
from sklearn.preprocessing import LabelEncoder

# For Scaling
from sklearn.preprocessing import StandardScaler

# For Feature Importance
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# For Cross Validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss

# For Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Importing Datasets

# %%
train_original = pd.read_csv('train.csv')
test_original = pd.read_csv('test.csv')

# Making a copy of the datasets
train = train_original.copy()
test = test_original.copy()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            67463 non-null  int64
#  1   Loan Amount                   67463 non-null  int64
#  2   Funded Amount                 67463 non-null  int64
#  3   Funded Amount Investor        67463 non-null  float64
#  4   Term                          67463 non-null  int64
#  5   Batch Enrolled                67463 non-null  object
#  6   Interest Rate                 67463 non-null  float64
#  7   Grade                         67463 non-null  object
#  8   Sub Grade                     67463 non-null  object
#  9   Employment Duration           67463 non-null  object
#  10  Home Ownership                67463 non-null  float64
#  11  Verification Status           67463 non-null  object
#  12  Payment Plan                  67463 non-null  object
#  13  Loan Title                    67463 non-null  object
#  14  Debit to Income               67463 non-null  float64
#  15  Delinquency - two years       67463 non-null  int64
#  16  Inquires - six months         67463 non-null  int64
#  17  Open Account                  67463 non-null  int64
#  18  Public Record                 67463 non-null  int64
#  19  Revolving Balance             67463 non-null  int64
#  20  Revolving Utilities           67463 non-null  float64
#  21  Total Accounts                67463 non-null  int64
#  22  Initial List Status           67463 non-null  object
#  23  Total Received Interest       67463 non-null  float64
#  24  Total Received Late Fee       67463 non-null  float64
#  25  Recoveries                    67463 non-null  float64
#  26  Collection Recovery Fee       67463 non-null  float64
#  27  Collection 12 months Medical  67463 non-null  int64
#  28  Application Type              67463 non-null  object
#  29  Last week Pay                 67463 non-null  int64
#  30  Accounts Delinquent           67463 non-null  int64
#  31  Total Collection Amount       67463 non-null  int64
#  32  Total Current Balance         67463 non-null  int64
#  33  Total Revolving Credit Limit  67463 non-null  int64
#  34  Loan Status                   67463 non-null  int64
# dtypes: float64(9), int64(17), object(9)
# memory usage: 18.0+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28913 entries, 0 to 28912
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            28913 non-null  int64
#  1   Loan Amount                   28913 non-null  int64
#  2   Funded Amount                 28913 non-null  int64
#  3   Funded Amount Investor        28913 non-null  float64
#  4   Term                          28913 non-null  int64
#  5   Batch Enrolled                28913 non-null  object
#  6   Interest Rate                 28913 non-null  float64
#  7   Grade                         28913 non-null  object
#  8   Sub Grade                     28913 non-null  object
#  9   Employment Duration           28913 non-null  object
#  10  Home Ownership                28913 non-null  float64
#  11  Verification Status           28913 non-null  object
#  12  Payment Plan                  28913 non-null  object
#  13  Loan Title                    28913 non-null  object
#  14  Debit to Income               28913 non-null  float64
#  15  Delinquency - two years       28913 non-null  int64
#  16  Inquires - six months         28913 non-null  int64
#  17  Open Account                  28913 non-null  int64
#  18  Public Record                 28913 non-null  int64
#  19  Revolving Balance             28913 non-null  int64
#  20  Revolving Utilities           28913 non-null  float64
#  21  Total Accounts                28913 non-null  int64
#  22  Initial List Status           28913 non-null  object
#  23  Total Received Interest       28913 non-null  float64
#  24  Total Received Late Fee       28913 non-null  float64
#  25  Recoveries                    28913 non-null  float64
#  26  Collection Recovery Fee       28913 non-null  float64
#  27  Collection 12 months Medical  28913 non-null  int64
#  28  Application Type              28913 non-null  object
#  29  Last week Pay                 28913 non-null  int64
#  30  Accounts Delinquent           28913 non-null  int64
#  31  Total Collection Amount       28913 non-null  int64
#  32  Total Current Balance         28913 non-null  int64
#  33  Total Revolving Credit Limit  28913 non-null  int64
#  34  Loan Status                   0 non-null      float64
# dtypes: float64(10), int64(16), object(9)
# memory usage: 7.7+ MB

# %%
train.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  6.746300e+04  67463.000000   67463.000000            67463.000000
# mean   2.562761e+07  16848.902776   15770.599114            14621.799323
# std    2.109155e+07   8367.865726    8150.992662             6785.345170
# min    1.297933e+06   1014.000000    1014.000000             1114.590204
# 25%    6.570288e+06  10012.000000    9266.500000             9831.684984
# 50%    1.791565e+07  16073.000000   13042.000000            12793.682170
# 75%    4.271521e+07  22106.000000   21793.000000            17807.594120
# max    7.224578e+07  35000.000000   34999.000000            34999.746430
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  67463.000000   67463.000000    67463.000000     67463.000000
# mean      58.173814      11.846258    80541.502522        23.299241
# std        3.327441       3.718629    45029.120366         8.451824
# min       36.000000       5.320006    14573.537170         0.675299
# 25%       58.000000       9.297147    51689.843335        16.756416
# 50%       59.000000      11.377696    69335.832680        22.656658
# 75%       59.000000      14.193533    94623.322785        30.048400
# max       59.000000      27.182348   406561.536400        39.629862
#
#        Delinquency - two years  Inquires - six months  ...  \
# count             67463.000000           67463.000000  ...
# mean                  0.327127               0.145754  ...
# std                   0.800888               0.473291  ...
# min                   0.000000               0.000000  ...
# 25%                   0.000000               0.000000  ...
# 50%                   0.000000               0.000000  ...
# 75%                   0.000000               0.000000  ...
# max                   8.000000               5.000000  ...
#
#        Total Received Late Fee    Recoveries  Collection Recovery Fee  \
# count             67463.000000  67463.000000             67463.000000
# mean                  1.143969     59.691578                 1.125141
# std                   5.244365    357.026346                 3.489885
# min                   0.000003      0.000036                 0.000036
# 25%                   0.021114      1.629818                 0.476259
# 50%                   0.043398      3.344524                 0.780141
# 75%                   0.071884      5.453727                 1.070566
# max                  42.618882   4354.467419               166.833000
#
#        Collection 12 months Medical  Last week Pay  Accounts Delinquent  \
# count                  67463.000000   67463.000000              67463.0
# mean                       0.021301      71.163260                  0.0
# std                        0.144385      43.315845                  0.0
# min                        0.000000       0.000000                  0.0
# 25%                        0.000000      35.000000                  0.0
# 50%                        0.000000      68.000000                  0.0
# 75%                        0.000000     105.000000                  0.0
# max                        1.000000     161.000000                  0.0
#
#        Total Collection Amount  Total Current Balance  \
# count             67463.000000           6.746300e+04
# mean                146.467990           1.595739e+05
# std                 744.382233           1.390332e+05
# min                   1.000000           6.170000e+02
# 25%                  24.000000           5.037900e+04
# 50%                  36.000000           1.183690e+05
# 75%                  46.000000           2.283750e+05
# max               16421.000000           1.177412e+06
#
#        Total Revolving Credit Limit   Loan Status
# count                  67463.000000  67463.000000
# mean                   23123.005544      0.092510
# std                    20916.699999      0.289747
# min                     1000.000000      0.000000
# 25%                     8155.500000      0.000000
# 50%                    16733.000000      0.000000
# 75%                    32146.500000      0.000000
# max                   201169.000000      1.000000
#
# [8 rows x 26 columns]

# %%
test.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  2.891300e+04  28913.000000   28913.000000            28913.000000
# mean   2.944966e+07  16404.027462   15619.911113            14741.536698
# std    2.206842e+07   8358.898287    8229.977503             7230.397758
# min    1.297893e+06   1000.000000    1000.000000             1000.000000
# 25%    8.272049e+06   9776.000000    9175.000000             9695.445501
# 50%    2.596622e+07  15600.000000   13200.000000            12930.601270
# 75%    4.855801e+07  21651.000000   21552.000000            19226.397540
# max    7.226845e+07  35000.000000   35000.000000            35000.000000
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  28913.000000   28913.000000    28913.000000     28913.000000
# mean      54.543078      12.187577    79983.752348        22.159266
# std        8.991800       3.911259    45231.316383         8.657629
# min       36.000000       5.320000    14907.925920         0.730000
# 25%       58.000000       9.422042    50791.000000        15.622891
# 50%       59.000000      11.688652    68894.324470        21.530000
# 75%       59.000000      14.640000    94684.941810        28.840000
# max       60.000000      27.310000   406944.859000        39.629977
#
#        Delinquency - two years  Inquires - six months  ...  \
# count             28913.000000           28913.000000  ...
# mean                  0.332065               0.276900  ...
# std                   0.818869               0.663999  ...
# min                   0.000000               0.000000  ...
# 25%                   0.000000               0.000000  ...
# 50%                   0.000000               0.000000  ...
# 75%                   0.000000               0.000000  ...
# max                   9.000000               5.000000  ...
#
#        Total Received Late Fee    Recoveries  Collection Recovery Fee  \
# count             28913.000000  28913.000000             28913.000000
# mean                  0.922863     50.624944                 1.393220
# std                   4.765042    336.450176                15.139809
# min                   0.000000      0.000000                 0.000000
# 25%                   0.000000      0.000000                 0.000000
# 50%                   0.027878      2.165909                 0.579620
# 75%                   0.061107      4.610188                 0.974739
# max                  42.520996   4325.594909               743.166000
#
#        Collection 12 months Medical  Last week Pay  Accounts Delinquent  \
# count                  28913.000000   28913.000000         28913.000000
# mean                       0.019576      65.007574             0.000968
# std                        0.138540      42.494090             0.031105
# min                        0.000000       0.000000             0.000000
# 25%                        0.000000      29.000000             0.000000
# 50%                        0.000000      60.000000             0.000000
# 75%                        0.000000      95.000000             0.000000
# max                        1.000000     161.000000             1.000000
#
#        Total Collection Amount  Total Current Balance  \
# count             28913.000000           2.891300e+04
# mean                159.747553           1.530975e+05
# std                 911.671785           1.391309e+05
# min                   0.000000           6.260000e+02
# 25%                   3.000000           4.397200e+04
# 50%                  30.000000           1.092860e+05
# 75%                  44.000000           2.222960e+05
# max               27076.000000           1.183282e+06
#
#        Total Revolving Credit Limit  Loan Status
# count                  28913.000000          0.0
# mean                   25013.808425          NaN
# std                    22284.519460          NaN
# min                     1000.000000          NaN
# 25%                     9325.000000          NaN
# 50%                    18848.000000          NaN
# 75%                    33860.000000          NaN
# max                   233500.000000          NaN
#
# [8 rows x 26 columns]

# %% [markdown]
# It is observed that Accounts Delinquent doesn't add any value in the train dataset. It will be removed

# %%
train.describe(include ='object')
# Out:
#        Batch Enrolled  Grade Sub Grade Employment Duration  \
# count           67463  67463     67463               67463
# unique             41      7        35                   3
# top        BAT3873588      C        B4            MORTGAGE
# freq             3626  19085      4462               36351
#
#        Verification Status Payment Plan               Loan Title  \
# count                67463        67463                    67463
# unique                   3            1                      109
# top        Source Verified            n  Credit card refinancing
# freq                 33036        67463                    30728
#
#        Initial List Status Application Type
# count                67463            67463
# unique                   2                2
# top                      w       INDIVIDUAL
# freq                 36299            67340

# %%
test.describe(include ='object')
# Out:
#        Batch Enrolled  Grade Sub Grade Employment Duration  \
# count           28913  28913     28913               28913
# unique             41      7        35                   3
# top        BAT3873588      C        B4            MORTGAGE
# freq             1623   8104      1902               15530
#
#        Verification Status Payment Plan          Loan Title  \
# count                28913        28913               28913
# unique                   3            1                 109
# top        Source Verified            n  Debt consolidation
# freq                 13626        28913               12259
#
#        Initial List Status Application Type
# count                28913            28913
# unique                   2                2
# top                      w       INDIVIDUAL
# freq                 15848            28883

# %% [markdown]
# -  Payment Plan has only 1 unique value. Again, it doesn't add value to our analysis and will be removed.
# -  Employment Duration has 3 unique values with one of them being MORTGAGE. The column is wrongly named. This column denotes Home Ownership.
# -  Loan Title has 109 unique values. These can be grouped into categories.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Combining Datasets

# %%
df = pd.concat([train, test],axis = 0).reset_index(drop = True)
df = pd.concat([test.assign(ind='test'), train.assign(ind='train')], axis = 0)

# %%
# Change the names of the columns Employment Duration, Home Ownership and Debit to Income Ratio
df.rename(columns={'Employment Duration': 'Home Ownership', 'Home Ownership': 'Employment Duration', 'Debit to Income':'Debt to Income'}, inplace=True)

# %%
# Remove space in the columns
df.columns = df.columns.str.replace('-','')
df.columns = df.columns.str.replace(' ','_')

# %%
df['Available_Accounts'] = df['Total_Accounts'] - df['Open_Account']

# %% [markdown]
# #### Removing Unnecessary Variables

# %%
## 1. Remove columns that don't value to the analysis
df.drop(['ID','Accounts_Delinquent','Payment_Plan','Sub_Grade','Total_Accounts','Open_Account'],axis=1, inplace=True)

# %%
## 2. Remove variables that are generated upon post approval of the loan. 
# Since, we have to predict if a loan applicant will default on a loan or not, including features generated after loan approval will cause data leakage. 
# It will further lead to overfitting and the model may not work well with the test dataset. Therefore, these variables will be removed.
df.drop(['Delinquency__two_years','Revolving_Balance','Revolving_Utilities','Total_Received_Interest','Total_Received_Late_Fee','Recoveries','Collection_Recovery_Fee',
'Collection_12_months_Medical','Last_week_Pay','Total_Revolving_Credit_Limit','Total_Collection_Amount','Total_Current_Balance'],axis=1, inplace=True)

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# Loan_Amount                   0
# Funded_Amount                 0
# Funded_Amount_Investor        0
# Term                          0
# Batch_Enrolled                0
# Interest_Rate                 0
# Grade                         0
# Home_Ownership                0
# Employment_Duration           0
# Verification_Status           0
# Loan_Title                    0
# Debt_to_Income                0
# Inquires__six_months          0
# Public_Record                 0
# Initial_List_Status           0
# Application_Type              0
# Loan_Status               28913
# ind                           0
# Available_Accounts            0
# dtype: int64

# %% [markdown]
# There are not any missing values in the independent variables. Loan status is the target variable and hence there are missing values belonging to observations from test dataset.

# %% [markdown]
# ### Outlier Treatment

# %%
sns.boxplot(df['Loan_Amount'])
# Out:
# <AxesSubplot:xlabel='Loan_Amount'>

# %%
sns.boxplot(df['Funded_Amount'])
# Out:
# <AxesSubplot:xlabel='Funded_Amount'>

# %%
sns.boxplot(df['Funded_Amount_Investor'])
# Out:
# <AxesSubplot:xlabel='Funded_Amount_Investor'>

# %%
sns.boxplot(df['Interest_Rate'])
# Out:
# <AxesSubplot:xlabel='Interest_Rate'>

# %%
sns.boxplot(df['Debt_to_Income'])
# Out:
# <AxesSubplot:xlabel='Debt_to_Income'>

# %%
sns.boxplot(df['Employment_Duration'])
# Out:
# <AxesSubplot:xlabel='Employment_Duration'>

# %% [markdown]
# The unit of Employment Duration is not specified. However, as the range of values extends from 0 to 400000+, it appears to be number of hours. Hence, it is converted to years.

# %%
df['Employment_Duration'] = df['Employment_Duration']/(365*24)

# %%
sns.boxplot(df['Employment_Duration'])
# Out:
# <AxesSubplot:xlabel='Employment_Duration'>

# %%
sns.boxplot(df['Available_Accounts'])
# Out:
# <AxesSubplot:xlabel='Available_Accounts'>

# %% [markdown]
# Available accounts cannot be negative values. This is mostly likely due to incorrect inputation of Total Accounts and Open Account where Open Account > Total Accounts. Hence, we will take the absolute values of Available_Accounts.

# %%
df['Available_Accounts'] = abs(df['Available_Accounts'])

# %% [markdown]
# #### Examining Loan Amount, Funded Amount and Funded Amount Investor

# %%
df.loc[(df['Loan_Amount']< df['Funded_Amount_Investor']) & (df['Loan_Amount']< df['Funded_Amount_Investor'])]
# Out:
#        Loan_Amount  Funded_Amount  Funded_Amount_Investor  Term  \
# 1             7133          11650             12615.79560    59
# 6            16214          16482             32939.84051    58
# 7             7569          23752             22807.69607    36
# 10           12429          16487             19194.48569    58
# 14            3789           7104             11390.17398    58
# ...            ...            ...                     ...   ...
# 67450         8664          34707             14474.59493    59
# 67455         5127          16956             13917.48522    59
# 67457        11440          17672             22965.76290    59
# 67459         8323          11046             15637.46301    59
# 67461        16567           4975             21353.68465    59
#
#       Batch_Enrolled  Interest_Rate Grade Home_Ownership  Employment_Duration  \
# 1         BAT2833642       6.564296     B       MORTGAGE             4.346919
# 6         BAT1104812       7.403273     C       MORTGAGE             3.014673
# 7         BAT2078974      10.512555     B       MORTGAGE             7.492324
# 10        BAT2136391      10.141490     B       MORTGAGE             9.884359
# 14        BAT4351734      19.821265     C       MORTGAGE             5.691127
# ...              ...            ...   ...            ...                  ...
# 67450     BAT2136391       9.468804     C       MORTGAGE             6.513565
# 67455     BAT2522922      19.388683     C       MORTGAGE            11.386819
# 67457     BAT2558388      15.025260     C           RENT             8.690501
# 67459     BAT1780517       9.972104     C           RENT             7.476156
# 67461     BAT2333412      13.169095     D            OWN            11.066077
#
#       Verification_Status               Loan_Title  Debt_to_Income  \
# 1         Source Verified  Credit card refinancing       18.157975
# 6         Source Verified  Credit card refinancing       32.280671
# 7         Source Verified  Credit card refinancing       18.187011
# 10        Source Verified  Credit card refinancing       29.449584
# 14               Verified  Credit card refinancing       19.340065
# ...                   ...                      ...             ...
# 67450            Verified         Medical expenses       38.863933
# 67455     Source Verified  Credit card refinancing       33.622294
# 67457            Verified       Debt consolidation       21.929698
# 67459     Source Verified  Credit card refinancing       17.694279
# 67461        Not Verified       Debt consolidation        7.614624
#
#        Inquires__six_months  Public_Record Initial_List_Status  \
# 1                         0              0                   w
# 6                         0              0                   f
# 7                         0              0                   w
# 10                        0              0                   w
# 14                        0              0                   f
# ...                     ...            ...                 ...
# 67450                     0              0                   f
# 67455                     0              0                   f
# 67457                     0              0                   w
# 67459                     0              0                   w
# 67461                     0              0                   f
#
#       Application_Type  Loan_Status    ind  Available_Accounts
# 1           INDIVIDUAL          NaN   test                  10
# 6           INDIVIDUAL          NaN   test                   2
# 7           INDIVIDUAL          NaN   test                   8
# 10          INDIVIDUAL          NaN   test                  39
# 14          INDIVIDUAL          NaN   test                  14
# ...                ...          ...    ...                 ...
# 67450       INDIVIDUAL          0.0  train                   6
# 67455       INDIVIDUAL          0.0  train                   8
# 67457       INDIVIDUAL          0.0  train                   1
# 67459       INDIVIDUAL          0.0  train                   2
# 67461       INDIVIDUAL          0.0  train                   1
#
# [37327 rows x 19 columns]

# %% [markdown]
# It is noticed that there are some observations where Loan Amount is lesser than Funded Amount and Funded Amount Investor.

# %%
df.loc[(df['Funded_Amount_Investor']> df['Loan_Amount']) & (df['Funded_Amount_Investor']> df['Funded_Amount'])]
# Out:
#        Loan_Amount  Funded_Amount  Funded_Amount_Investor  Term  \
# 1             7133          11650             12615.79560    59
# 6            16214          16482             32939.84051    58
# 10           12429          16487             19194.48569    58
# 14            3789           7104             11390.17398    58
# 16            9250           8009             15895.25957    36
# ...            ...            ...                     ...   ...
# 67445        12597          10573             25849.54390    59
# 67446        16710          22491             26614.64494    58
# 67457        11440          17672             22965.76290    59
# 67459         8323          11046             15637.46301    59
# 67461        16567           4975             21353.68465    59
#
#       Batch_Enrolled  Interest_Rate Grade Home_Ownership  Employment_Duration  \
# 1         BAT2833642       6.564296     B       MORTGAGE             4.346919
# 6         BAT1104812       7.403273     C       MORTGAGE             3.014673
# 10        BAT2136391      10.141490     B       MORTGAGE             9.884359
# 14        BAT4351734      19.821265     C       MORTGAGE             5.691127
# 16        BAT1930365      11.679298     C           RENT             5.611413
# ...              ...            ...   ...            ...                  ...
# 67445     BAT1586599      15.255265     C       MORTGAGE            18.594222
# 67446     BAT5341619      10.458293     C       MORTGAGE             4.342291
# 67457     BAT2558388      15.025260     C           RENT             8.690501
# 67459     BAT1780517       9.972104     C           RENT             7.476156
# 67461     BAT2333412      13.169095     D            OWN            11.066077
#
#       Verification_Status               Loan_Title  Debt_to_Income  \
# 1         Source Verified  Credit card refinancing       18.157975
# 6         Source Verified  Credit card refinancing       32.280671
# 10        Source Verified  Credit card refinancing       29.449584
# 14               Verified  Credit card refinancing       19.340065
# 16               Verified  Credit card refinancing       13.916413
# ...                   ...                      ...             ...
# 67445     Source Verified         Home improvement       22.809975
# 67446        Not Verified  Credit card refinancing       19.171569
# 67457            Verified       Debt consolidation       21.929698
# 67459     Source Verified  Credit card refinancing       17.694279
# 67461        Not Verified       Debt consolidation        7.614624
#
#        Inquires__six_months  Public_Record Initial_List_Status  \
# 1                         0              0                   w
# 6                         0              0                   f
# 10                        0              0                   w
# 14                        0              0                   f
# 16                        0              0                   w
# ...                     ...            ...                 ...
# 67445                     0              0                   w
# 67446                     0              0                   f
# 67457                     0              0                   w
# 67459                     0              0                   w
# 67461                     0              0                   f
#
#       Application_Type  Loan_Status    ind  Available_Accounts
# 1           INDIVIDUAL          NaN   test                  10
# 6           INDIVIDUAL          NaN   test                   2
# 10          INDIVIDUAL          NaN   test                  39
# 14          INDIVIDUAL          NaN   test                  14
# 16          INDIVIDUAL          NaN   test                   9
# ...                ...          ...    ...                 ...
# 67445       INDIVIDUAL          0.0  train                   2
# 67446       INDIVIDUAL          0.0  train                   1
# 67457       INDIVIDUAL          0.0  train                   1
# 67459       INDIVIDUAL          0.0  train                   2
# 67461       INDIVIDUAL          0.0  train                   1
#
# [23063 rows x 19 columns]

# %% [markdown]
# Similarly, there are observations where Funded Amount Investor is greater than Funded Amount and Funded Amount Investor.

# %% [markdown]
# Funded amount is the loan disbursed by the bank to the applicant/representative. Therefore, loan amount too cannot be less than the funded amount.
# Similarly, funded amount investor cannot be more than the loan amount or funded amount. Funded amount investor could mean amount invested or funded by a third party investor. Essentially these values are outliers and have been interchanged.
#
# A possible solution for this problem is substitution of values by comparison of the three variables: Loan Amount, Funded Amount, Funded Amount Investor.
#  - Loan Amount > Funded Amount > Funded Amount Investor
#
# Hence, the lowest of these three variables in a particular observation has to be funded amount investor and highest will be the loan amount.
# Funded amount can be dropped as loan amount can be disbursed only after loan is approved.

# %%
# Create new columns for Loan Amount and Funded Amount Investor
df['Actual_Loan_Amount'] = df['Loan_Amount']
df['Actual_Funded_Amount_Investor'] = df['Funded_Amount_Investor']

# Calculate the maximum value of the three columns for Loan Amount
df['Actual_Loan_Amount'] = df[['Loan_Amount','Funded_Amount','Funded_Amount_Investor']].max(axis=1)

# Calculate the minimum value of the three columns for Funded Amount Investor
df['Actual_Funded_Amount_Investor'] = df[['Loan_Amount','Funded_Amount','Funded_Amount_Investor']].min(axis=1)

# %%
## Loan Amount, Funded Amount and Funded Amount Investor are all dropped. 
df.drop(['Loan_Amount','Funded_Amount','Funded_Amount_Investor'], axis=1, inplace = True)

# %% [markdown]
# ### Inconsistent Labels

# %%
df['Verification_Status'].unique()
# Out:
# array(['Source Verified', 'Verified', 'Not Verified'], dtype=object)

# %%
df['Loan_Title'].unique()
# Out:
# array(['Home improvement', 'Credit card refinancing',
#        'Debt consolidation', 'Debt Consolidation', 'CC Loan',
#        'credit card refinance', 'Credit Card Consolidation', 'MYLOAN',
#        'Other', 'CC Consolidation', 'Moving and relocation', 'Car Loan',
#        'Bill Payoff', 'Car financing', 'Personal', 'Credit Consolidation',
#        'credit card consolidation', 'Home Improvement', 'Personal Loan',
#        'Medical expenses', 'personal', 'Consolidation', 'CONSOLIDATE',
#        'Refinance', 'Business', 'DEBT CONSOLIDATION', 'Major purchase',
#        'Home Improvement Loan', 'refi', 'Credit Card Debt',
#        'Consolidation Loan', 'consolidation loan', 'Vacation',
#        'debt consolidation', 'consolidate', 'Consolidate',
#        'Credit card payoff', 'Credit Card Refinance', 'home improvement',
#        'payoff', 'Debt Consolidation Loan', 'Credit Cards',
#        'CC-Refinance', 'Debt payoff', 'debt consolidation loan',
#        'Credit card pay off', 'Green loan', 'loan1', 'credit card',
#        'CONSOLIDATION', 'Home buying', 'Loan 1', 'Credit Card Refi',
#        'Pool', 'Cards', 'My Loan', 'Get Debt Free', 'Pay Off', 'House',
#        'debt', 'Dept consolidation', 'Freedom', 'consolidation',
#        'Credit Loan', 'Debt Free', 'Lending Club', 'Card Consolidation',
#        'CC consolidation', 'Debt Loan', 'Debt Payoff', 'Credit Card Loan',
#        'Loan Consolidation', 'relief', 'Home', 'Debt Reduction', 'Debt',
#        'Credit Card Payoff', 'CC', 'cards', 'Payoff', 'conso',
#        'Credit card refinance', 'Bill Consolidation', 'Medical loan',
#        'Wedding Loan', 'Loan', 'Credit payoff', 'Credit Card',
#        'Credit Card consolidation', 'CC Refi', 'pay off bills',
#        'Lending loan', 'debt loan', 'CC Refinance', 'Bathroom',
#        'vacation', 'Getting Ahead', 'Refinance Loan', 'bills',
#        'Personal loan', 'get out of debt', 'Home loan', 'Consolidated',
#        'Debt Consolidation 2013', 'Credit', 'Medical',
#        'Credit Card Paydown', 'Credit Card Refinance Loan',
#        'credit pay off'], dtype=object)

# %% [markdown]
# Columns Verification Status and Loan Title have inconsistent labels. It can be corrected using dictionaries for each column.

# %%
## Correct the labels in Verification Status
dict = {'Source Verified': 'Verified','Verified':'Verified','Not Verified':'Not Verified'}
df['Verification_Status'].replace(dict, inplace = True)

# %%
title = pd.DataFrame(df['Loan_Title'].value_counts())

# %%
## Correct the labels in Loan Title
title_dict = {'Debt Consolidation 2013': 'debt_consolidation','Debt Reduction':'debt_consolidation','Debt':'debt_consolidation','conso':'debt_consolidation',
'debt loan': 'debt_consolidation','get out of debt':'debt_consolidation','Consolidated':'debt_consolidation','Debt Payoff':'debt_consolidation',
'Loan Consolidation': 'debt_consolidation','relief':'debt_consolidation','Lending Club':'debt_consolidation','Debt Loan':'debt_consolidation',
'CONSOLIDATION': 'debt_consolidation','Get Debt Free':'debt_consolidation','Freedom':'debt_consolidation','consolidation':'debt_consolidation','Lending loan':'debt_consolidation',
'Debt Free': 'debt_consolidation','Debt Consolidation Loan':'debt_consolidation','Debt payoff':'debt_consolidation','debt consolidation loan':'debt_consolidation',
'Consolidation': 'debt_consolidation','Debt Consolidation':'debt_consolidation','Debt consolidation':'debt_consolidation','CONSOLIDATE':'debt_consolidation',
'DEBT CONSOLIDATION': 'debt_consolidation','Consolidation Loan':'debt_consolidation','consolidation loan':'debt_consolidation','debt consolidation':'debt_consolidation',
'consolidate': 'debt_consolidation','Consolidate':'debt_consolidation','debt':'debt_consolidation','Credit Card':'credit_card','Credit Card consolidation':'credit_card',
'Dept consolidation':'debt_consolidation','CC Refi': 'credit_card','pay off bills':'credit_card','CC-Refinance':'credit_card','Refinance Loan':'credit_card',
'bills': 'credit_card','Credit':'credit_card','Credit Card Paydown':'credit_card','Credit Card Refinance Loan':'credit_card',
'credit pay off': 'credit_card','Credit card refinancing':'credit_card','CC Loan':'credit_card','credit card refinance':'credit_card',
'Credit Card Loan': 'credit_card','Credit Card Consolidation':'credit_card','Card Consolidation':'credit_card','CC consolidation':'credit_card',
'Bill Payoff': 'credit_card','Credit Consolidation':'credit_card','credit card consolidation':'credit_card','Refinance':'credit_card',
'refi':'credit_card','Credit Card Debt':'credit_card','Credit card payoff':'credit_card','Credit Card Refinance':'credit_card','CC Consolidation':'credit_card',
'payoff':'credit_card','Credit Cards':'credit_card','CC Refinance':'credit_card','Credit card pay off':'credit_card','cards':'credit_card',
'credit card':'credit_card','Credit Card Refi':'credit_card','Cards':'credit_card','Pay Off':'credit_card',
'Credit Loan':'credit_card','Credit Card Payoff':'credit_card','CC':'credit_card','Payoff':'credit_card',
'Credit card refinance':'credit_card','Bill Consolidation':'credit_card','Credit payoff':'credit_card','Home improvement':'BuyingHouse&HomeImprovement',
'Home Improvement':'BuyingHouse&HomeImprovement','Home Improvement Loan':'BuyingHouse&HomeImprovement','home improvement':'BuyingHouse&HomeImprovement','Pool':'BuyingHouse&HomeImprovement',
'Home buying':'BuyingHouse&HomeImprovement','House':'BuyingHouse&HomeImprovement','Home':'BuyingHouse&HomeImprovement','Bathroom':'BuyingHouse&HomeImprovement',
'Home loan':'BuyingHouse&HomeImprovement','Getting Ahead': 'BuyingHouse&HomeImprovement','Moving and relocation':'moving','other':'Other','vacation':'vacation',
'Vacation':'vacation','Wedding Loan':'wedding','MYLOAN':'personal','Personal':'personal',
'Personal Loan': 'personal','loan1':'personal','Loan 1':'personal','My Loan':'personal',
'Loan': 'personal','Personal loan':'personal','Major purchase':'major_purchase','Medical expenses':'medical',
'Medical loan': 'medical','Medical':'medical','Car Loan':'car','Car financing':'car',
'car':'car','Business': 'business','Green loan':'renewable_energy'}
df['Loan_Title'].replace(title_dict, inplace = True)

# %%
df['Loan_Title'].unique()
# Out:
# array(['BuyingHouse&HomeImprovement', 'credit_card', 'debt_consolidation',
#        'personal', 'Other', 'moving', 'car', 'medical', 'business',
#        'major_purchase', 'vacation', 'renewable_energy', 'wedding'],
#       dtype=object)

# %% [markdown]
# ## Splitting into Train and Test Dataset

# %%
test, train = df[df['ind'].eq('test')], df[df['ind'].eq('train')]

# %%
# Drop 'ind' column from test and train datasets
train.drop(['ind'], axis=1, inplace=True)
test.drop(['ind','Loan_Status'], axis=1, inplace=True)

# %% [markdown]
# 1. Overall Distribution of Loan Status

# %%
## Overall distribution of Loan Status

#Countplot of loan status
plt.figure(figsize=(10,3))
ax=sns.countplot(y='Loan_Status',data=df, palette='hls',order = train['Loan_Status'].value_counts().index)
plt.title('Loan Status Distribution')
total = len(train['Loan_Status'])
for p in ax.patches:
        percentage = '{:.3f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
plt.show()

# %% [markdown]
# Out of 67463 loan applicants, 90.75% applicants are non-defaulters and 9.25% have defaulted.
#
# This also means that the train dataset is imbalanced. To resolve this, stratified K-fold cross validation with shuffle setting as True will be used to ensure equal distribution of the Loan Status labels during building the model.

# %% [markdown]
# ## Encoding Categorical Variables

# %% [markdown]
# As we will be using tree-based algorithms for building the model, we shall choose label encoding for encoding categorical variables.

# %%
features = ['Grade','Home_Ownership','Verification_Status','Initial_List_Status','Application_Type','Loan_Title', 'Batch_Enrolled']

le = LabelEncoder()

# Fit the encoder and tranform each column
for col in features:
    train.loc[:, col]= le.fit_transform(train[col])
    test.loc[:, col]= le.transform(test[col])

train = pd.DataFrame(train, columns = train.columns)
test = pd.DataFrame(test, columns = test.columns)

# %% [markdown]
# ### Splitting into X and y

# %%
X_train = train.drop(columns = ['Loan_Status'], axis=1)
y_train = train['Loan_Status']

# %%
y_train.unique()
# Out:
# array([0., 1.])

# %% [markdown]
# ## Scaling

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67463 entries, 0 to 67462
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Term                           67463 non-null  int64
#  1   Batch_Enrolled                 67463 non-null  int32
#  2   Interest_Rate                  67463 non-null  float64
#  3   Grade                          67463 non-null  int32
#  4   Home_Ownership                 67463 non-null  int32
#  5   Employment_Duration            67463 non-null  float64
#  6   Verification_Status            67463 non-null  int32
#  7   Loan_Title                     67463 non-null  int32
#  8   Debt_to_Income                 67463 non-null  float64
#  9   Inquires__six_months           67463 non-null  int64
#  10  Public_Record                  67463 non-null  int64
#  11  Initial_List_Status            67463 non-null  int32
#  12  Application_Type               67463 non-null  int32
#  13  Available_Accounts             67463 non-null  int64
#  14  Actual_Loan_Amount             67463 non-null  float64
#  15  Actual_Funded_Amount_Investor  67463 non-null  float64
# dtypes: float64(5), int32(7), int64(4)
# memory usage: 6.9 MB

# %%
# List for columns to scale
cols_to_scale = ['Term','Interest_Rate','Employment_Duration','Debt_to_Income','Inquires__six_months','Public_Record',
'Available_Accounts','Actual_Loan_Amount','Actual_Funded_Amount_Investor']

# Create scaler
scaler = StandardScaler()

# Create a copy of the datasets
X_train_scaled = X_train.copy()
test_scaled = test.copy()

# Scale selected data
X_train_scaled[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
test_scaled[cols_to_scale] = scaler.transform(test[cols_to_scale])
test_scaled = pd.DataFrame(test_scaled, columns = test.columns)

# %%
X_train_scaled
# Out:
#            Term  Batch_Enrolled  Interest_Rate  Grade  Home_Ownership  \
# 0      0.248297              16      -0.191268      1               0
# 1      0.248297               4       0.105229      2               2
# 2      0.248297              11       0.188142      5               0
# 3      0.248297              15       1.313651      2               0
# 4      0.248297              32       0.850331      2               0
# ...         ...             ...            ...    ...             ...
# 67458  0.248297              21      -0.655461      2               0
# 67459  0.248297               7      -0.503994      2               2
# 67460  0.248297               5       2.098823      0               0
# 67461  0.248297              14       0.355735      3               1
# 67462  0.248297               8       1.126330      1               0
#
#        Employment_Duration  Verification_Status  Loan_Title  Debt_to_Income  \
# 0                 2.127642                    0           5       -0.829943
# 1                -0.904035                    1           5       -0.933158
# 2                 0.243515                    1           5        0.572470
# 3                 0.616163                    1           5       -0.621824
# 4                -0.806299                    1           4       -0.720484
# ...                    ...                  ...         ...             ...
# 67458             0.075944                    1           4        0.568625
# 67459            -0.334239                    1           4       -0.663171
# 67460            -1.015518                    1           5       -1.538551
# 67461             0.364152                    0           5       -1.855781
# 67462             0.545910                    1           5       -0.857470
#
#        Inquires__six_months  Public_Record  Initial_List_Status  \
# 0                 -0.307961      -0.234958                    1
# 1                 -0.307961      -0.234958                    0
# 2                 -0.307961      -0.234958                    1
# 3                 -0.307961      -0.234958                    1
# 4                  6.030678       2.650186                    1
# ...                     ...            ...                  ...
# 67458             -0.307961      -0.234958                    1
# 67459             -0.307961      -0.234958                    1
# 67460             -0.307961       2.650186                    1
# 67461             -0.307961      -0.234958                    0
# 67462             -0.307961      -0.234958                    0
#
#        Application_Type  Available_Accounts  Actual_Loan_Amount  \
# 0                     0           -0.412089            1.361814
# 1                     0           -1.132752           -1.516654
# 2                     0           -0.412089            0.793129
# 3                     0           -0.556221           -0.700223
# 4                     0            0.020309           -0.841986
# ...                 ...                 ...                 ...
# 67458                 0           -0.412089           -1.314311
# 67459                 0           -0.988619           -1.021859
# 67460                 0           -0.988619            1.460186
# 67461                 0           -1.132752           -0.200967
# 67462                 0            0.740973            1.022757
#
#        Actual_Funded_Amount_Investor
# 0                           0.133911
# 1                          -1.456003
# 2                          -0.037494
# 3                          -0.623854
# 4                           0.936455
# ...                              ...
# 67458                      -0.650224
# 67459                      -0.283283
# 67460                       0.713419
# 67461                      -1.116178
# 67462                       1.180614
#
# [67463 rows x 16 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Defin feature selection 
selector = SelectKBest(f_regression, k = 'all')

# Apply transformation to the training set
X_new = selector.fit_transform(X_train_scaled, y_train)  

# Get names of the selected features
mask = selector.get_support()     

# Scores for selected features
print(selector.scores_)     

# Get a list of selected features
new_features = X_train_scaled.columns[mask]
print(new_features)   

X = X_train_scaled[new_features]
test = test_scaled[new_features]
# Out:
# [7.84323001e-01 4.12242175e+00 5.67292449e-01 9.16882431e+00
#  9.59767792e+00 9.31442970e-01 3.99485730e-02 1.25643378e+00
#  6.30579087e-01 2.25560917e-02 7.56695859e+00 1.21961813e+01
#  1.39153699e-02 5.02477458e+00 7.21468716e-03 4.96289671e+00]
# Index(['Term', 'Batch_Enrolled', 'Interest_Rate', 'Grade', 'Home_Ownership',
#        'Employment_Duration', 'Verification_Status', 'Loan_Title',
#        'Debt_to_Income', 'Inquires__six_months', 'Public_Record',
#        'Initial_List_Status', 'Application_Type', 'Available_Accounts',
#        'Actual_Loan_Amount', 'Actual_Funded_Amount_Investor'],
#       dtype='object')

# %% [markdown]
# ## Building the Machine Learning Models

# %%
# Implement cross validation
def skfold_cv(X, y, algorithm, params,n_jobs=-1):
    skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)
 
 
    for train_index , test_index in skf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]

        model = algorithm(**params) 
        model.fit(X_train,y_train)
        pred = model.predict_proba(X_test)[:,1]
        pred_clipped = np.clip(pred,0.05,0.95)

        score = log_loss(y_test, pred)
        print(f'score: {score}')
        
    return model

# %% [markdown]
# ### 1. Logistic Regression Model

# %%
## Initial Logit model
logit_params = {}
logit_model = skfold_cv(X,y_train,LogisticRegression,logit_params)
# Out:
# score: 0.3082716380510674
# score: 0.3082144587502548
# score: 0.3082584853932116
# score: 0.30808068760928853
# score: 0.308006570548865

# %%
# Hyperparameter Tuning for Logistic Regression
from sklearn import model_selection

# Define a grid of parameters
param_grid = {'penalty': ['l1','l2'],
'C': [0.001,0.01,0.1,1,10,100],}

# Initialize grid search
classifier = LogisticRegression(n_jobs=-1,random_state=42)

model = model_selection.RandomizedSearchCV(estimator=classifier,
param_distributions=param_grid,
scoring='neg_log_loss',
verbose=10,
n_jobs=1,
cv=StratifiedKFold(5,shuffle=True))

# Fit the model and extract best score
model.fit(X, y_train)
print(f'Best score: {model.best_score_}')
print('Best parameters set:')
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f'\t{param_name}: {best_parameters[param_name]}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START C=0.001, penalty=l1........................................
# [CV 1/5; 1/10] END ......................C=0.001, penalty=l1; total time=   0.0s
# [CV 2/5; 1/10] START C=0.001, penalty=l1........................................
# [CV 2/5; 1/10] END ......................C=0.001, penalty=l1; total time=   0.0s
# [CV 3/5; 1/10] START C=0.001, penalty=l1........................................
# [CV 3/5; 1/10] END ......................C=0.001, penalty=l1; total time=   0.0s
# [CV 4/5; 1/10] START C=0.001, penalty=l1........................................
# [CV 4/5; 1/10] END ......................C=0.001, penalty=l1; total time=   0.0s
# [CV 5/5; 1/10] START C=0.001, penalty=l1........................................
# [CV 5/5; 1/10] END ......................C=0.001, penalty=l1; total time=   0.0s
# [CV 1/5; 2/10] START C=1, penalty=l2............................................
# [CV 1/5; 2/10] END ..........................C=1, penalty=l2; total time=   4.6s
# [CV 2/5; 2/10] START C=1, penalty=l2............................................
# [CV 2/5; 2/10] END ..........................C=1, penalty=l2; total time=   4.4s
# [CV 3/5; 2/10] START C=1, penalty=l2............................................
# [CV 3/5; 2/10] END ..........................C=1, penalty=l2; total time=   2.8s
# [CV 4/5; 2/10] START C=1, penalty=l2............................................
# [CV 4/5; 2/10] END ..........................C=1, penalty=l2; total time=   3.5s
# [CV 5/5; 2/10] START C=1, penalty=l2............................................
# [CV 5/5; 2/10] END ..........................C=1, penalty=l2; total time=   3.2s
# [CV 1/5; 3/10] START C=100, penalty=l2..........................................
# [CV 1/5; 3/10] END ........................C=100, penalty=l2; total time=   2.7s
# [CV 2/5; 3/10] START C=100, penalty=l2..........................................
# [CV 2/5; 3/10] END ........................C=100, penalty=l2; total time=   2.7s
# [CV 3/5; 3/10] START C=100, penalty=l2..........................................
# [CV 3/5; 3/10] END ........................C=100, penalty=l2; total time=   2.5s
# [CV 4/5; 3/10] START C=100, penalty=l2..........................................
# [CV 4/5; 3/10] END ........................C=100, penalty=l2; total time=   3.1s
# [CV 5/5; 3/10] START C=100, penalty=l2..........................................
# [CV 5/5; 3/10] END ........................C=100, penalty=l2; total time=   2.7s
# [CV 1/5; 4/10] START C=0.01, penalty=l1.........................................
# [CV 1/5; 4/10] END .......................C=0.01, penalty=l1; total time=   0.0s
# [CV 2/5; 4/10] START C=0.01, penalty=l1.........................................
# [CV 2/5; 4/10] END .......................C=0.01, penalty=l1; total time=   0.0s
# [CV 3/5; 4/10] START C=0.01, penalty=l1.........................................
# [CV 3/5; 4/10] END .......................C=0.01, penalty=l1; total time=   0.0s
# [CV 4/5; 4/10] START C=0.01, penalty=l1.........................................
# [CV 4/5; 4/10] END .......................C=0.01, penalty=l1; total time=   0.0s
# [CV 5/5; 4/10] START C=0.01, penalty=l1.........................................
# [CV 5/5; 4/10] END .......................C=0.01, penalty=l1; total time=   0.0s
# [CV 1/5; 5/10] START C=10, penalty=l1...........................................
# [CV 1/5; 5/10] END .........................C=10, penalty=l1; total time=   0.0s
# [CV 2/5; 5/10] START C=10, penalty=l1...........................................
# [CV 2/5; 5/10] END .........................C=10, penalty=l1; total time=   0.0s
# [CV 3/5; 5/10] START C=10, penalty=l1...........................................
# [CV 3/5; 5/10] END .........................C=10, penalty=l1; total time=   0.0s
# [CV 4/5; 5/10] START C=10, penalty=l1...........................................
# [CV 4/5; 5/10] END .........................C=10, penalty=l1; total time=   0.0s
# [CV 5/5; 5/10] START C=10, penalty=l1...........................................
# [CV 5/5; 5/10] END .........................C=10, penalty=l1; total time=   0.0s
# [CV 1/5; 6/10] START C=0.01, penalty=l2.........................................
# [CV 1/5; 6/10] END .......................C=0.01, penalty=l2; total time=   2.6s
# [CV 2/5; 6/10] START C=0.01, penalty=l2.........................................
# [CV 2/5; 6/10] END .......................C=0.01, penalty=l2; total time=   3.4s
# [CV 3/5; 6/10] START C=0.01, penalty=l2.........................................
# [CV 3/5; 6/10] END .......................C=0.01, penalty=l2; total time=   1.4s
# [CV 4/5; 6/10] START C=0.01, penalty=l2.........................................
# [CV 4/5; 6/10] END .......................C=0.01, penalty=l2; total time=   1.8s
# [CV 5/5; 6/10] START C=0.01, penalty=l2.........................................
# [CV 5/5; 6/10] END .......................C=0.01, penalty=l2; total time=   1.8s
# [CV 1/5; 7/10] START C=0.1, penalty=l2..........................................
# [CV 1/5; 7/10] END ........................C=0.1, penalty=l2; total time=   2.4s
# [CV 2/5; 7/10] START C=0.1, penalty=l2..........................................
# [CV 2/5; 7/10] END ........................C=0.1, penalty=l2; total time=   1.7s
# [CV 3/5; 7/10] START C=0.1, penalty=l2..........................................
# [CV 3/5; 7/10] END ........................C=0.1, penalty=l2; total time=   1.4s
# [CV 4/5; 7/10] START C=0.1, penalty=l2..........................................
# [CV 4/5; 7/10] END ........................C=0.1, penalty=l2; total time=   1.9s
# [CV 5/5; 7/10] START C=0.1, penalty=l2..........................................
# [CV 5/5; 7/10] END ........................C=0.1, penalty=l2; total time=   1.9s
# [CV 1/5; 8/10] START C=0.1, penalty=l1..........................................
# [CV 1/5; 8/10] END ........................C=0.1, penalty=l1; total time=   0.0s
# [CV 2/5; 8/10] START C=0.1, penalty=l1..........................................
# [CV 2/5; 8/10] END ........................C=0.1, penalty=l1; total time=   0.0s
# [CV 3/5; 8/10] START C=0.1, penalty=l1..........................................
# [CV 3/5; 8/10] END ........................C=0.1, penalty=l1; total time=   0.0s
# [CV 4/5; 8/10] START C=0.1, penalty=l1..........................................
# [CV 4/5; 8/10] END ........................C=0.1, penalty=l1; total time=   0.0s
# [CV 5/5; 8/10] START C=0.1, penalty=l1..........................................
# [CV 5/5; 8/10] END ........................C=0.1, penalty=l1; total time=   0.0s
# [CV 1/5; 9/10] START C=0.001, penalty=l2........................................
# [CV 1/5; 9/10] END ......................C=0.001, penalty=l2; total time=   2.1s
# [CV 2/5; 9/10] START C=0.001, penalty=l2........................................
# [CV 2/5; 9/10] END ......................C=0.001, penalty=l2; total time=   1.0s
# [CV 3/5; 9/10] START C=0.001, penalty=l2........................................
# [CV 3/5; 9/10] END ......................C=0.001, penalty=l2; total time=   1.4s
# [CV 4/5; 9/10] START C=0.001, penalty=l2........................................
# [CV 4/5; 9/10] END ......................C=0.001, penalty=l2; total time=   1.0s
# [CV 5/5; 9/10] START C=0.001, penalty=l2........................................
# [CV 5/5; 9/10] END ......................C=0.001, penalty=l2; total time=   1.2s
# [CV 1/5; 10/10] START C=100, penalty=l1.........................................
# [CV 1/5; 10/10] END .......................C=100, penalty=l1; total time=   0.0s
# [CV 2/5; 10/10] START C=100, penalty=l1.........................................
# [CV 2/5; 10/10] END .......................C=100, penalty=l1; total time=   0.0s
# [CV 3/5; 10/10] START C=100, penalty=l1.........................................
# [CV 3/5; 10/10] END .......................C=100, penalty=l1; total time=   0.0s
# [CV 4/5; 10/10] START C=100, penalty=l1.........................................
# [CV 4/5; 10/10] END .......................C=100, penalty=l1; total time=   0.0s
# [CV 5/5; 10/10] START C=100, penalty=l1.........................................
# [CV 5/5; 10/10] END .......................C=100, penalty=l1; total time=   0.0s
# Best score: -0.30813946451123614
# Best parameters set:
# 	C: 0.001
# 	penalty: l2

# %%
## Logit model with tuned hyperparameters
logit_params = {'penalty':'l2','C': 0.001}
logit_model = skfold_cv(X,y_train,LogisticRegression,logit_params)
# Out:
# score: 0.30823440001231156
# score: 0.3080295203353197
# score: 0.3082369384466084
# score: 0.30807867001386646
# score: 0.30799747404415767

# %% [markdown]
# ### 2. Random Forest Model

# %%
## Initial Random Forest model
rf_params = {}
rf_model = skfold_cv(X, y_train,RandomForestClassifier,rf_params)
# Out:
# score: 0.3233814188771744
# score: 0.31910500951069953
# score: 0.3248871127929232
# score: 0.321229580364105
# score: 0.31803196402633604

# %%
## Hyperparameter Tuning for Random Forest Classifier
from sklearn import model_selection

# Define a grid of parameters
param_grid = {'n_estimators': [100, 200, 250, 300, 400, 500],
'max_depth': [1, 2, 5, 7, 11, 15],
'criterion': ['gini', 'entropy'],
'min_samples_split': [1, 2, 5, 10, 15, 100],
'min_samples_leaf': [1, 2, 5, 10],
'max_features': ['log2', 'sqrt','None']}

# Initialize randomized search
classifier = RandomForestClassifier(n_jobs=-1,random_state=42)

model = model_selection.RandomizedSearchCV(estimator=classifier,
param_distributions=param_grid,
scoring='neg_log_loss',
verbose=10,
n_jobs=1,
cv=StratifiedKFold(5,shuffle=True))

# Fit the model and extract best score
model.fit(X, y_train)
print(f'Best score: {model.best_score_}')
print('Best parameters set:')
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f'\t{param_name}: {best_parameters[param_name]}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 1/5; 1/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.4s
# [CV 2/5; 1/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 2/5; 1/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   3.4s
# [CV 3/5; 1/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 3/5; 1/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   2.6s
# [CV 4/5; 1/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 4/5; 1/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   2.8s
# [CV 5/5; 1/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 5/5; 1/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   2.7s
# [CV 1/5; 2/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250
# [CV 1/5; 2/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250; total time=   8.0s
# [CV 2/5; 2/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250
# [CV 2/5; 2/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250; total time=   5.2s
# [CV 3/5; 2/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250
# [CV 3/5; 2/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250; total time=   5.3s
# [CV 4/5; 2/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250
# [CV 4/5; 2/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250; total time=   5.5s
# [CV 5/5; 2/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250
# [CV 5/5; 2/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=250; total time=   5.5s
# [CV 1/5; 3/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 1/5; 3/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV 2/5; 3/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 2/5; 3/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV 3/5; 3/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 3/5; 3/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV 4/5; 3/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 4/5; 3/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.8s
# [CV 5/5; 3/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 5/5; 3/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.1s
# [CV 1/5; 4/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 1/5; 4/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   1.1s
# [CV 2/5; 4/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 2/5; 4/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV 3/5; 4/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 3/5; 4/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   1.0s
# [CV 4/5; 4/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 4/5; 4/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV 5/5; 4/10] START criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 5/5; 4/10] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV 1/5; 5/10] START criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/5; 5/10] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV 2/5; 5/10] START criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/5; 5/10] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV 3/5; 5/10] START criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/5; 5/10] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV 4/5; 5/10] START criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 4/5; 5/10] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV 5/5; 5/10] START criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 5/5; 5/10] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV 1/5; 6/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250
# [CV 1/5; 6/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250; total time=   1.7s
# [CV 2/5; 6/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250
# [CV 2/5; 6/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250; total time=   1.8s
# [CV 3/5; 6/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250
# [CV 3/5; 6/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250; total time=   1.8s
# [CV 4/5; 6/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250
# [CV 4/5; 6/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV 5/5; 6/10] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250
# [CV 5/5; 6/10] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 1/5; 7/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.2s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 2/5; 7/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   2.7s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 3/5; 7/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   2.9s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 4/5; 7/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   3.0s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300
# [CV 5/5; 7/10] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   3.1s
# [CV 1/5; 8/10] START criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 1/5; 8/10] END criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV 2/5; 8/10] START criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 2/5; 8/10] END criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.9s
# [CV 3/5; 8/10] START criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 3/5; 8/10] END criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.9s
# [CV 4/5; 8/10] START criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 4/5; 8/10] END criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV 5/5; 8/10] START criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 5/5; 8/10] END criterion=entropy, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.8s
# [CV 1/5; 9/10] START criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300
# [CV 1/5; 9/10] END criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   2.8s
# [CV 2/5; 9/10] START criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300
# [CV 2/5; 9/10] END criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   2.9s
# [CV 3/5; 9/10] START criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300
# [CV 3/5; 9/10] END criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   3.0s
# [CV 4/5; 9/10] START criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300
# [CV 4/5; 9/10] END criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   2.9s
# [CV 5/5; 9/10] START criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300
# [CV 5/5; 9/10] END criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   3.6s
# [CV 1/5; 10/10] START criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300
# [CV 1/5; 10/10] END criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   5.0s
# [CV 2/5; 10/10] START criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300
# [CV 2/5; 10/10] END criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV 3/5; 10/10] START criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300
# [CV 3/5; 10/10] END criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.4s
# [CV 4/5; 10/10] START criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300
# [CV 4/5; 10/10] END criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.4s
# [CV 5/5; 10/10] START criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300
# [CV 5/5; 10/10] END criterion=gini, max_depth=2, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.4s
# Best score: -0.30803326830552785
# Best parameters set:
# 	criterion: gini
# 	max_depth: 5
# 	max_features: log2
# 	min_samples_leaf: 10
# 	min_samples_split: 5
# 	n_estimators: 200

# %%
## Random Forest model with tuned hyperparameters
rf_params = {'n_estimators':200,
'max_depth': 5,'criterion': 'gini',
'min_samples_split': 5,
'min_samples_leaf': 10,
'max_features':'log2'} 
rf_model = skfold_cv(X, y_train,RandomForestClassifier,rf_params)
# Out:
# score: 0.30822196630210824
# score: 0.3079083830984625
# score: 0.308395327526948
# score: 0.3081416785446496
# score: 0.3080343155319027

# %%
col_names = X.columns
importances = rf_model.feature_importances_
idxs = np.argsort(importances)
plt.title('Feature Importances')
plt.barh(range(len(idxs)), importances[idxs], align='center')
plt.yticks(range(len(idxs)), [col_names[i] for i in idxs])
plt.xlabel('Random Forest Feature Importance')
plt.show()

# %% [markdown]
# Although both logistic model and random forest model perform well with close log loss values, the random forest model with tuned hyperparameters is choosen as the final model.

# %% [markdown]
# ## Predicting results for Test dataset

# %%
rf_model.fit(X, y_train)
pred_rf= rf_model.predict_proba(test)[:,1]
pred_clipped = np.clip(pred_rf,0.05,0.95)

# %% [markdown]
# The use of this log loss as the evaluation metric will mete out extreme punishments for being both confident and wrong. In the worst possible case, a prediction which is true when it is actually false will add an huge amount to your error score. Therefore, it will be much better to keep our probabilities between 0.025–0.975 so that we are never very sure about our prediction.

# %%
pred_clipped
# Out:
# array([0.09749023, 0.0922361 , 0.0928126 , ..., 0.1021016 , 0.09558121,
#        0.09899102])

# %% [markdown]
# ### Adding Predicted Values to the Submission File

# %%
submission = pd.read_csv('submission.csv')
submission['Loan Status'] = pred_clipped
submission.to_csv('submission.csv', index=False)
